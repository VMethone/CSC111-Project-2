# %%
import pandas as pd

# Replace this with the actual path to the CSV file
csv_file_path = "US Airline Flight Routes and Fares 1993-2024 2.csv"

# Read the CSV into a pandas DataFrame
df = pd.read_csv(csv_file_path)


df.head()
# Out:
# /tmp/ipykernel_52/3342681967.py:7: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#        tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0  Table1a  2021        3           30135           33195
# 1  Table1a  2021        3           30135           33195
# 2  Table1a  2021        3           30140           30194
# 3  Table1a  2021        3           30140           30194
# 4  Table1a  2021        3           30140           30466
#
#                             city1                          city2  airportid_1  \
# 0  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 1  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 2                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# 3                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# 4                 Albuquerque, NM                    Phoenix, AZ        10140
#
#    airportid_2 airport_1  ...    fare  carrier_lg  large_ms  fare_lg  \
# 0        14112       ABE  ...   81.43          G4    1.0000    81.43
# 1        15304       ABE  ...  208.93          DL    0.4659   219.98
# 2        11259       ABQ  ...  184.56          WN    0.9968   184.44
# 3        11298       ABQ  ...  182.64          AA    0.9774   183.09
# 4        14107       ABQ  ...  177.11          WN    0.6061   184.49
#
#   carrier_low   lf_ms  fare_low Geocoded_City1  Geocoded_City2  \
# 0          G4  1.0000     81.43            NaN             NaN
# 1          UA  0.1193    154.11            NaN             NaN
# 2          WN  0.9968    184.44            NaN             NaN
# 3          AA  0.9774    183.09            NaN             NaN
# 4          AA  0.3939    165.77            NaN             NaN
#
#                  tbl1apk
# 0  202131013514112ABEPIE
# 1  202131013515304ABETPA
# 2  202131014011259ABQDAL
# 3  202131014011298ABQDFW
# 4  202131014014107ABQPHX
#
# [5 rows x 23 columns]

# %%
df
# Out:
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0       Table1a  2021        3           30135           33195
# 1       Table1a  2021        3           30135           33195
# 2       Table1a  2021        3           30140           30194
# 3       Table1a  2021        3           30140           30194
# 4       Table1a  2021        3           30140           30466
# ...         ...   ...      ...             ...             ...
# 245950  Table1a  2024        1           35412           31703
# 245951  Table1a  2024        1           35412           32467
# 245952  Table1a  2024        1           35412           32467
# 245953  Table1a  2024        1           35412           33195
# 245954  Table1a  2024        1           35412           33195
#
#                                  city1                                  city2  \
# 0       Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# 1       Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# 2                      Albuquerque, NM                  Dallas/Fort Worth, TX
# 3                      Albuquerque, NM                  Dallas/Fort Worth, TX
# 4                      Albuquerque, NM                            Phoenix, AZ
# ...                                ...                                    ...
# 245950                   Knoxville, TN  New York City, NY (Metropolitan Area)
# 245951                   Knoxville, TN          Miami, FL (Metropolitan Area)
# 245952                   Knoxville, TN          Miami, FL (Metropolitan Area)
# 245953                   Knoxville, TN          Tampa, FL (Metropolitan Area)
# 245954                   Knoxville, TN          Tampa, FL (Metropolitan Area)
#
#         airportid_1  airportid_2 airport_1  ...    fare  carrier_lg  large_ms  \
# 0             10135        14112       ABE  ...   81.43          G4    1.0000
# 1             10135        15304       ABE  ...  208.93          DL    0.4659
# 2             10140        11259       ABQ  ...  184.56          WN    0.9968
# 3             10140        11298       ABQ  ...  182.64          AA    0.9774
# 4             10140        14107       ABQ  ...  177.11          WN    0.6061
# ...             ...          ...       ...  ...     ...         ...       ...
# 245950        15412        12953       TYS  ...  278.70          DL    0.7503
# 245951        15412        11697       TYS  ...  148.69          G4    0.8255
# 245952        15412        13303       TYS  ...  330.19          AA    0.8057
# 245953        15412        14112       TYS  ...   95.65          G4    1.0000
# 245954        15412        15304       TYS  ...  330.15          AA    0.5212
#
#         fare_lg carrier_low   lf_ms  fare_low Geocoded_City1  Geocoded_City2  \
# 0         81.43          G4  1.0000     81.43            NaN             NaN
# 1        219.98          UA  0.1193    154.11            NaN             NaN
# 2        184.44          WN  0.9968    184.44            NaN             NaN
# 3        183.09          AA  0.9774    183.09            NaN             NaN
# 4        184.49          AA  0.3939    165.77            NaN             NaN
# ...         ...         ...     ...       ...            ...             ...
# 245950   287.44          AA  0.2359    248.46            NaN             NaN
# 245951   114.45          G4  0.8255    114.45            NaN             NaN
# 245952   321.92          AA  0.8057    321.92            NaN             NaN
# 245953    95.65          G4  1.0000     95.65            NaN             NaN
# 245954   288.38          AA  0.5212    288.38            NaN             NaN
#
#                       tbl1apk
# 0       202131013514112ABEPIE
# 1       202131013515304ABETPA
# 2       202131014011259ABQDAL
# 3       202131014011298ABQDFW
# 4       202131014014107ABQPHX
# ...                       ...
# 245950  202411541212953TYSLGA
# 245951  202411541211697TYSFLL
# 245952  202411541213303TYSMIA
# 245953  202411541214112TYSPIE
# 245954  202411541215304TYSTPA
#
# [245955 rows x 23 columns]

# %%
# Define a function to categorize the year
def categorize_period(year):
    if 2018 <= year <= 2020:
        return "Pre-Pandemic"
    elif 2021 <= year <= 2022:
        return "During-Pandemic"
    elif 2023 <= year <= 2024:
        return "Post-Pandemic"
    else:
        return "Other"

# Apply the function to create a new column
df['period'] = df['Year'].apply(categorize_period)

# %%
df
# Out:
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0       Table1a  2021        3           30135           33195
# 1       Table1a  2021        3           30135           33195
# 2       Table1a  2021        3           30140           30194
# 3       Table1a  2021        3           30140           30194
# 4       Table1a  2021        3           30140           30466
# ...         ...   ...      ...             ...             ...
# 245950  Table1a  2024        1           35412           31703
# 245951  Table1a  2024        1           35412           32467
# 245952  Table1a  2024        1           35412           32467
# 245953  Table1a  2024        1           35412           33195
# 245954  Table1a  2024        1           35412           33195
#
#                                  city1                                  city2  \
# 0       Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# 1       Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# 2                      Albuquerque, NM                  Dallas/Fort Worth, TX
# 3                      Albuquerque, NM                  Dallas/Fort Worth, TX
# 4                      Albuquerque, NM                            Phoenix, AZ
# ...                                ...                                    ...
# 245950                   Knoxville, TN  New York City, NY (Metropolitan Area)
# 245951                   Knoxville, TN          Miami, FL (Metropolitan Area)
# 245952                   Knoxville, TN          Miami, FL (Metropolitan Area)
# 245953                   Knoxville, TN          Tampa, FL (Metropolitan Area)
# 245954                   Knoxville, TN          Tampa, FL (Metropolitan Area)
#
#         airportid_1  airportid_2 airport_1  ... carrier_lg  large_ms  fare_lg  \
# 0             10135        14112       ABE  ...         G4    1.0000    81.43
# 1             10135        15304       ABE  ...         DL    0.4659   219.98
# 2             10140        11259       ABQ  ...         WN    0.9968   184.44
# 3             10140        11298       ABQ  ...         AA    0.9774   183.09
# 4             10140        14107       ABQ  ...         WN    0.6061   184.49
# ...             ...          ...       ...  ...        ...       ...      ...
# 245950        15412        12953       TYS  ...         DL    0.7503   287.44
# 245951        15412        11697       TYS  ...         G4    0.8255   114.45
# 245952        15412        13303       TYS  ...         AA    0.8057   321.92
# 245953        15412        14112       TYS  ...         G4    1.0000    95.65
# 245954        15412        15304       TYS  ...         AA    0.5212   288.38
#
#         carrier_low   lf_ms  fare_low  Geocoded_City1 Geocoded_City2  \
# 0                G4  1.0000     81.43             NaN            NaN
# 1                UA  0.1193    154.11             NaN            NaN
# 2                WN  0.9968    184.44             NaN            NaN
# 3                AA  0.9774    183.09             NaN            NaN
# 4                AA  0.3939    165.77             NaN            NaN
# ...             ...     ...       ...             ...            ...
# 245950           AA  0.2359    248.46             NaN            NaN
# 245951           G4  0.8255    114.45             NaN            NaN
# 245952           AA  0.8057    321.92             NaN            NaN
# 245953           G4  1.0000     95.65             NaN            NaN
# 245954           AA  0.5212    288.38             NaN            NaN
#
#                       tbl1apk           period
# 0       202131013514112ABEPIE  During-Pandemic
# 1       202131013515304ABETPA  During-Pandemic
# 2       202131014011259ABQDAL  During-Pandemic
# 3       202131014011298ABQDFW  During-Pandemic
# 4       202131014014107ABQPHX  During-Pandemic
# ...                       ...              ...
# 245950  202411541212953TYSLGA    Post-Pandemic
# 245951  202411541211697TYSFLL    Post-Pandemic
# 245952  202411541213303TYSMIA    Post-Pandemic
# 245953  202411541214112TYSPIE    Post-Pandemic
# 245954  202411541215304TYSTPA    Post-Pandemic
#
# [245955 rows x 24 columns]

# %%
# Apply the function to create a new column
df['period'] = df['Year'].apply(categorize_period)

# Keep only the defined periods (drop "Other")
df = df[df['period'] != 'Other']

# Sort the DataFrame by Year and Quarter
df = df.sort_values(by=['Year', 'quarter']).reset_index(drop=True)

df
# Out:
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0      Table 1a  2018        1           30372           31703
# 1      Table 1a  2018        1           30372           32575
# 2      Table 1a  2018        1           30372           32575
# 3      Table 1a  2018        1           30140           32575
# 4      Table 1a  2018        1           30140           30852
# ...         ...   ...      ...             ...             ...
# 49118   Table1a  2024        1           35412           31703
# 49119   Table1a  2024        1           35412           32467
# 49120   Table1a  2024        1           35412           32467
# 49121   Table1a  2024        1           35412           33195
# 49122   Table1a  2024        1           35412           33195
#
#                  city1                                  city2  airportid_1  \
# 0            Aspen, CO  New York City, NY (Metropolitan Area)        10372
# 1            Aspen, CO    Los Angeles, CA (Metropolitan Area)        10372
# 2            Aspen, CO    Los Angeles, CA (Metropolitan Area)        10372
# 3      Albuquerque, NM    Los Angeles, CA (Metropolitan Area)        10140
# 4      Albuquerque, NM     Washington, DC (Metropolitan Area)        10140
# ...                ...                                    ...          ...
# 49118    Knoxville, TN  New York City, NY (Metropolitan Area)        15412
# 49119    Knoxville, TN          Miami, FL (Metropolitan Area)        15412
# 49120    Knoxville, TN          Miami, FL (Metropolitan Area)        15412
# 49121    Knoxville, TN          Tampa, FL (Metropolitan Area)        15412
# 49122    Knoxville, TN          Tampa, FL (Metropolitan Area)        15412
#
#        airportid_2 airport_1  ... carrier_lg  large_ms  fare_lg  carrier_low  \
# 0            12953       ASE  ...         UA    0.7254   530.23           AA
# 1            12954       ASE  ...         AA    0.5000   286.80           AA
# 2            13891       ASE  ...         UA    0.5556   286.20           AA
# 3            10800       ABQ  ...         WN    0.8396   178.51           WN
# 4            10821       ABQ  ...         WN    0.8861   272.49           UA
# ...            ...       ...  ...        ...       ...      ...          ...
# 49118        12953       TYS  ...         DL    0.7503   287.44           AA
# 49119        11697       TYS  ...         G4    0.8255   114.45           G4
# 49120        13303       TYS  ...         AA    0.8057   321.92           AA
# 49121        14112       TYS  ...         G4    1.0000    95.65           G4
# 49122        15304       TYS  ...         AA    0.5212   288.38           AA
#
#         lf_ms  fare_low                             Geocoded_City1  \
# 0      0.2241    449.37        Aspen, CO\n(39.190665, -106.819201)
# 1      0.5000    286.80        Aspen, CO\n(39.190665, -106.819201)
# 2      0.2222    255.75        Aspen, CO\n(39.190665, -106.819201)
# 3      0.8396    178.51  Albuquerque, NM\n(35.084248, -106.649241)
# 4      0.0462    268.15  Albuquerque, NM\n(35.084248, -106.649241)
# ...       ...       ...                                        ...
# 49118  0.2359    248.46                                        NaN
# 49119  0.8255    114.45                                        NaN
# 49120  0.8057    321.92                                        NaN
# 49121  1.0000     95.65                                        NaN
# 49122  0.5212    288.38                                        NaN
#
#                                           Geocoded_City2  \
# 0      New York City, NY (Metropolitan Area)\n(40.123...
# 1      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 2      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 3      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 4      Washington, DC (Metropolitan Area)\n(38.892062...
# ...                                                  ...
# 49118                                                NaN
# 49119                                                NaN
# 49120                                                NaN
# 49121                                                NaN
# 49122                                                NaN
#
#                      tbl1apk         period
# 0      201811037212953ASELGA   Pre-Pandemic
# 1      201811037212954ASELGB   Pre-Pandemic
# 2      201811037213891ASEONT   Pre-Pandemic
# 3      201811014010800ABQBUR   Pre-Pandemic
# 4      201811014010821ABQBWI   Pre-Pandemic
# ...                      ...            ...
# 49118  202411541212953TYSLGA  Post-Pandemic
# 49119  202411541211697TYSFLL  Post-Pandemic
# 49120  202411541213303TYSMIA  Post-Pandemic
# 49121  202411541214112TYSPIE  Post-Pandemic
# 49122  202411541215304TYSTPA  Post-Pandemic
#
# [49123 rows x 24 columns]

# %%
# Step 1: Create a lookup dictionary from rows where geocoded data exists
geo_lookup = df.dropna(subset=['Geocoded_City1', 'Geocoded_City2']) \
               .drop_duplicates(subset=['city1', 'city2']) \
               .set_index(['city1', 'city2'])[['Geocoded_City1', 'Geocoded_City2']]

# Step 2: Define a function to fill missing geocoded values using the lookup
def fill_geocodes(row):
    if pd.isna(row['Geocoded_City1']) or pd.isna(row['Geocoded_City2']):
        key = (row['city1'], row['city2'])
        if key in geo_lookup.index:
            if pd.isna(row['Geocoded_City1']):
                row['Geocoded_City1'] = geo_lookup.loc[key, 'Geocoded_City1']
            if pd.isna(row['Geocoded_City2']):
                row['Geocoded_City2'] = geo_lookup.loc[key, 'Geocoded_City2']
    return row

# Step 3: Apply the function to the whole DataFrame
df = df.apply(fill_geocodes, axis=1)

df
# Out:
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0      Table 1a  2018        1           30372           31703
# 1      Table 1a  2018        1           30372           32575
# 2      Table 1a  2018        1           30372           32575
# 3      Table 1a  2018        1           30140           32575
# 4      Table 1a  2018        1           30140           30852
# ...         ...   ...      ...             ...             ...
# 49118   Table1a  2024        1           35412           31703
# 49119   Table1a  2024        1           35412           32467
# 49120   Table1a  2024        1           35412           32467
# 49121   Table1a  2024        1           35412           33195
# 49122   Table1a  2024        1           35412           33195
#
#                  city1                                  city2  airportid_1  \
# 0            Aspen, CO  New York City, NY (Metropolitan Area)        10372
# 1            Aspen, CO    Los Angeles, CA (Metropolitan Area)        10372
# 2            Aspen, CO    Los Angeles, CA (Metropolitan Area)        10372
# 3      Albuquerque, NM    Los Angeles, CA (Metropolitan Area)        10140
# 4      Albuquerque, NM     Washington, DC (Metropolitan Area)        10140
# ...                ...                                    ...          ...
# 49118    Knoxville, TN  New York City, NY (Metropolitan Area)        15412
# 49119    Knoxville, TN          Miami, FL (Metropolitan Area)        15412
# 49120    Knoxville, TN          Miami, FL (Metropolitan Area)        15412
# 49121    Knoxville, TN          Tampa, FL (Metropolitan Area)        15412
# 49122    Knoxville, TN          Tampa, FL (Metropolitan Area)        15412
#
#        airportid_2 airport_1  ... carrier_lg  large_ms  fare_lg  carrier_low  \
# 0            12953       ASE  ...         UA    0.7254   530.23           AA
# 1            12954       ASE  ...         AA    0.5000   286.80           AA
# 2            13891       ASE  ...         UA    0.5556   286.20           AA
# 3            10800       ABQ  ...         WN    0.8396   178.51           WN
# 4            10821       ABQ  ...         WN    0.8861   272.49           UA
# ...            ...       ...  ...        ...       ...      ...          ...
# 49118        12953       TYS  ...         DL    0.7503   287.44           AA
# 49119        11697       TYS  ...         G4    0.8255   114.45           G4
# 49120        13303       TYS  ...         AA    0.8057   321.92           AA
# 49121        14112       TYS  ...         G4    1.0000    95.65           G4
# 49122        15304       TYS  ...         AA    0.5212   288.38           AA
#
#         lf_ms  fare_low                             Geocoded_City1  \
# 0      0.2241    449.37        Aspen, CO\n(39.190665, -106.819201)
# 1      0.5000    286.80        Aspen, CO\n(39.190665, -106.819201)
# 2      0.2222    255.75        Aspen, CO\n(39.190665, -106.819201)
# 3      0.8396    178.51  Albuquerque, NM\n(35.084248, -106.649241)
# 4      0.0462    268.15  Albuquerque, NM\n(35.084248, -106.649241)
# ...       ...       ...                                        ...
# 49118  0.2359    248.46     Knoxville, TN\n(35.962631, -83.916677)
# 49119  0.8255    114.45     Knoxville, TN\n(35.962631, -83.916677)
# 49120  0.8057    321.92     Knoxville, TN\n(35.962631, -83.916677)
# 49121  1.0000     95.65                    (35.962631, -83.916677)
# 49122  0.5212    288.38                    (35.962631, -83.916677)
#
#                                           Geocoded_City2  \
# 0      New York City, NY (Metropolitan Area)\n(40.123...
# 1      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 2      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 3      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 4      Washington, DC (Metropolitan Area)\n(38.892062...
# ...                                                  ...
# 49118  New York City, NY (Metropolitan Area)\n(40.123...
# 49119  Miami, FL (Metropolitan Area)\n(44.977479, -93...
# 49120  Miami, FL (Metropolitan Area)\n(44.977479, -93...
# 49121                              (37.8606, -78.804199)
# 49122                              (37.8606, -78.804199)
#
#                      tbl1apk         period
# 0      201811037212953ASELGA   Pre-Pandemic
# 1      201811037212954ASELGB   Pre-Pandemic
# 2      201811037213891ASEONT   Pre-Pandemic
# 3      201811014010800ABQBUR   Pre-Pandemic
# 4      201811014010821ABQBWI   Pre-Pandemic
# ...                      ...            ...
# 49118  202411541212953TYSLGA  Post-Pandemic
# 49119  202411541211697TYSFLL  Post-Pandemic
# 49120  202411541213303TYSMIA  Post-Pandemic
# 49121  202411541214112TYSPIE  Post-Pandemic
# 49122  202411541215304TYSTPA  Post-Pandemic
#
# [49123 rows x 24 columns]

# %%
# --- Step 1: Define what a valid geocode is (must include city + coordinates)
def is_valid_geocode(val):
    return isinstance(val, str) and "," in val and "(" in val and ")" in val and not val.strip().startswith("(")

# --- Step 2: Create lookup from only valid geocoded entries
valid_geo = df[
    df['Geocoded_City1'].apply(is_valid_geocode) &
    df['Geocoded_City2'].apply(is_valid_geocode)
]

# Build lookup dictionary based on (city1, city2) pairs
geo_lookup = valid_geo.drop_duplicates(subset=['city1', 'city2']) \
                      .set_index(['city1', 'city2'])[['Geocoded_City1', 'Geocoded_City2']]

# --- Step 3: Function to fill in both missing and incomplete geocodes
def fill_geocodes(row):
    key = (row['city1'], row['city2'])

    if key in geo_lookup.index:
        # Fill if missing or incomplete
        if not is_valid_geocode(row['Geocoded_City1']):
            row['Geocoded_City1'] = geo_lookup.loc[key, 'Geocoded_City1']
        if not is_valid_geocode(row['Geocoded_City2']):
            row['Geocoded_City2'] = geo_lookup.loc[key, 'Geocoded_City2']
    
    return row

# --- Step 4: Apply to entire DataFrame
df = df.apply(fill_geocodes, axis=1)

# --- Step 5 (Optional): Check remaining bad rows
bad_rows = df[
    df['Geocoded_City1'].apply(lambda x: not is_valid_geocode(x)) |
    df['Geocoded_City2'].apply(lambda x: not is_valid_geocode(x))
]
print(f"Remaining incomplete geocoded rows: {len(bad_rows)}")

df
# Out:
# Remaining incomplete geocoded rows: 0
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0      Table 1a  2018        1           30372           31703
# 1      Table 1a  2018        1           30372           32575
# 2      Table 1a  2018        1           30372           32575
# 3      Table 1a  2018        1           30140           32575
# 4      Table 1a  2018        1           30140           30852
# ...         ...   ...      ...             ...             ...
# 46794   Table1a  2024        1           35412           31703
# 46795   Table1a  2024        1           35412           31703
# 46796   Table1a  2024        1           35412           31703
# 46797   Table1a  2024        1           35412           32467
# 46798   Table1a  2024        1           35412           32467
#
#                  city1                                  city2  airportid_1  \
# 0            Aspen, CO  New York City, NY (Metropolitan Area)        10372
# 1            Aspen, CO    Los Angeles, CA (Metropolitan Area)        10372
# 2            Aspen, CO    Los Angeles, CA (Metropolitan Area)        10372
# 3      Albuquerque, NM    Los Angeles, CA (Metropolitan Area)        10140
# 4      Albuquerque, NM     Washington, DC (Metropolitan Area)        10140
# ...                ...                                    ...          ...
# 46794    Knoxville, TN  New York City, NY (Metropolitan Area)        15412
# 46795    Knoxville, TN  New York City, NY (Metropolitan Area)        15412
# 46796    Knoxville, TN  New York City, NY (Metropolitan Area)        15412
# 46797    Knoxville, TN          Miami, FL (Metropolitan Area)        15412
# 46798    Knoxville, TN          Miami, FL (Metropolitan Area)        15412
#
#        airportid_2 airport_1  ... carrier_lg  large_ms  fare_lg  carrier_low  \
# 0            12953       ASE  ...         UA    0.7254   530.23           AA
# 1            12954       ASE  ...         AA    0.5000   286.80           AA
# 2            13891       ASE  ...         UA    0.5556   286.20           AA
# 3            10800       ABQ  ...         WN    0.8396   178.51           WN
# 4            10821       ABQ  ...         WN    0.8861   272.49           UA
# ...            ...       ...  ...        ...       ...      ...          ...
# 46794        12197       TYS  ...         AA    0.7442   310.57           AA
# 46795        12478       TYS  ...         AA    0.5658   254.62           AA
# 46796        12953       TYS  ...         DL    0.7503   287.44           AA
# 46797        11697       TYS  ...         G4    0.8255   114.45           G4
# 46798        13303       TYS  ...         AA    0.8057   321.92           AA
#
#         lf_ms  fare_low                             Geocoded_City1  \
# 0      0.2241    449.37        Aspen, CO\n(39.190665, -106.819201)
# 1      0.5000    286.80        Aspen, CO\n(39.190665, -106.819201)
# 2      0.2222    255.75        Aspen, CO\n(39.190665, -106.819201)
# 3      0.8396    178.51  Albuquerque, NM\n(35.084248, -106.649241)
# 4      0.0462    268.15  Albuquerque, NM\n(35.084248, -106.649241)
# ...       ...       ...                                        ...
# 46794  0.7442    310.57     Knoxville, TN\n(35.962631, -83.916677)
# 46795  0.5658    254.62     Knoxville, TN\n(35.962631, -83.916677)
# 46796  0.2359    248.46     Knoxville, TN\n(35.962631, -83.916677)
# 46797  0.8255    114.45     Knoxville, TN\n(35.962631, -83.916677)
# 46798  0.8057    321.92     Knoxville, TN\n(35.962631, -83.916677)
#
#                                           Geocoded_City2  \
# 0      New York City, NY (Metropolitan Area)\n(40.123...
# 1      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 2      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 3      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 4      Washington, DC (Metropolitan Area)\n(38.892062...
# ...                                                  ...
# 46794  New York City, NY (Metropolitan Area)\n(40.123...
# 46795  New York City, NY (Metropolitan Area)\n(40.123...
# 46796  New York City, NY (Metropolitan Area)\n(40.123...
# 46797  Miami, FL (Metropolitan Area)\n(44.977479, -93...
# 46798  Miami, FL (Metropolitan Area)\n(44.977479, -93...
#
#                      tbl1apk         period
# 0      201811037212953ASELGA   Pre-Pandemic
# 1      201811037212954ASELGB   Pre-Pandemic
# 2      201811037213891ASEONT   Pre-Pandemic
# 3      201811014010800ABQBUR   Pre-Pandemic
# 4      201811014010821ABQBWI   Pre-Pandemic
# ...                      ...            ...
# 46794  202411541212197TYSHPN  Post-Pandemic
# 46795  202411541212478TYSJFK  Post-Pandemic
# 46796  202411541212953TYSLGA  Post-Pandemic
# 46797  202411541211697TYSFLL  Post-Pandemic
# 46798  202411541213303TYSMIA  Post-Pandemic
#
# [46799 rows x 24 columns]

# %%
df = df.drop(columns=['tbl'])

df
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2            city1  \
# 0      2018        1           30372           31703        Aspen, CO
# 1      2018        1           30372           32575        Aspen, CO
# 2      2018        1           30372           32575        Aspen, CO
# 3      2018        1           30140           32575  Albuquerque, NM
# 4      2018        1           30140           30852  Albuquerque, NM
# ...     ...      ...             ...             ...              ...
# 46794  2024        1           35412           31703    Knoxville, TN
# 46795  2024        1           35412           31703    Knoxville, TN
# 46796  2024        1           35412           31703    Knoxville, TN
# 46797  2024        1           35412           32467    Knoxville, TN
# 46798  2024        1           35412           32467    Knoxville, TN
#
#                                        city2  airportid_1  airportid_2  \
# 0      New York City, NY (Metropolitan Area)        10372        12953
# 1        Los Angeles, CA (Metropolitan Area)        10372        12954
# 2        Los Angeles, CA (Metropolitan Area)        10372        13891
# 3        Los Angeles, CA (Metropolitan Area)        10140        10800
# 4         Washington, DC (Metropolitan Area)        10140        10821
# ...                                      ...          ...          ...
# 46794  New York City, NY (Metropolitan Area)        15412        12197
# 46795  New York City, NY (Metropolitan Area)        15412        12478
# 46796  New York City, NY (Metropolitan Area)        15412        12953
# 46797          Miami, FL (Metropolitan Area)        15412        11697
# 46798          Miami, FL (Metropolitan Area)        15412        13303
#
#       airport_1 airport_2  ...  carrier_lg  large_ms  fare_lg carrier_low  \
# 0           ASE       LGA  ...          UA    0.7254   530.23          AA
# 1           ASE       LGB  ...          AA    0.5000   286.80          AA
# 2           ASE       ONT  ...          UA    0.5556   286.20          AA
# 3           ABQ       BUR  ...          WN    0.8396   178.51          WN
# 4           ABQ       BWI  ...          WN    0.8861   272.49          UA
# ...         ...       ...  ...         ...       ...      ...         ...
# 46794       TYS       HPN  ...          AA    0.7442   310.57          AA
# 46795       TYS       JFK  ...          AA    0.5658   254.62          AA
# 46796       TYS       LGA  ...          DL    0.7503   287.44          AA
# 46797       TYS       FLL  ...          G4    0.8255   114.45          G4
# 46798       TYS       MIA  ...          AA    0.8057   321.92          AA
#
#         lf_ms  fare_low                             Geocoded_City1  \
# 0      0.2241    449.37        Aspen, CO\n(39.190665, -106.819201)
# 1      0.5000    286.80        Aspen, CO\n(39.190665, -106.819201)
# 2      0.2222    255.75        Aspen, CO\n(39.190665, -106.819201)
# 3      0.8396    178.51  Albuquerque, NM\n(35.084248, -106.649241)
# 4      0.0462    268.15  Albuquerque, NM\n(35.084248, -106.649241)
# ...       ...       ...                                        ...
# 46794  0.7442    310.57     Knoxville, TN\n(35.962631, -83.916677)
# 46795  0.5658    254.62     Knoxville, TN\n(35.962631, -83.916677)
# 46796  0.2359    248.46     Knoxville, TN\n(35.962631, -83.916677)
# 46797  0.8255    114.45     Knoxville, TN\n(35.962631, -83.916677)
# 46798  0.8057    321.92     Knoxville, TN\n(35.962631, -83.916677)
#
#                                           Geocoded_City2  \
# 0      New York City, NY (Metropolitan Area)\n(40.123...
# 1      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 2      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 3      Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 4      Washington, DC (Metropolitan Area)\n(38.892062...
# ...                                                  ...
# 46794  New York City, NY (Metropolitan Area)\n(40.123...
# 46795  New York City, NY (Metropolitan Area)\n(40.123...
# 46796  New York City, NY (Metropolitan Area)\n(40.123...
# 46797  Miami, FL (Metropolitan Area)\n(44.977479, -93...
# 46798  Miami, FL (Metropolitan Area)\n(44.977479, -93...
#
#                      tbl1apk         period
# 0      201811037212953ASELGA   Pre-Pandemic
# 1      201811037212954ASELGB   Pre-Pandemic
# 2      201811037213891ASEONT   Pre-Pandemic
# 3      201811014010800ABQBUR   Pre-Pandemic
# 4      201811014010821ABQBWI   Pre-Pandemic
# ...                      ...            ...
# 46794  202411541212197TYSHPN  Post-Pandemic
# 46795  202411541212478TYSJFK  Post-Pandemic
# 46796  202411541212953TYSLGA  Post-Pandemic
# 46797  202411541211697TYSFLL  Post-Pandemic
# 46798  202411541213303TYSMIA  Post-Pandemic
#
# [46799 rows x 23 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# If needed, load the data
# df = pd.read_csv("your_cleaned_file.csv")

# Count the number of rows per year
year_counts = df['Year'].value_counts().sort_index()

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(year_counts.index, year_counts.values)
plt.xlabel("Year")
plt.ylabel("Number of Records")
plt.title("Number of Flight Records per Year")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.to_csv("filled_geocoded_airline_data.csv", index=False)
